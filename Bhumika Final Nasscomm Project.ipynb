# %%
import os
# !pip install kaggle -q
os.environ['KAGGLE_USERNAME'] = "bhumikareddyavuthu"
os.environ['KAGGLE_KEY'] = "d5395a3bbb727109e849ce9701a02a61"
# !kaggle datasets download "gunavenkatdoddi/eye-diseases-classification"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gunavenkatdoddi/eye-diseases-classification
# License(s): ODbL-1.0

# %%
# !unzip -q eye-diseases-classification.zip

# %%
import os
import cv2
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Corrected import statement
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import classification_report

# %%
labels = ["Normal", "Glaucoma", "Cataract", "Diabetic Retinopathy"]
counts = [1074,1007, 1038, 1098]

# %%
plt.figure(figsize=(10, 5))
plt.bar(labels, counts, color=['blue', 'red', 'green', 'purple'])
plt.xlabel("Type of eye disease")
plt.ylabel("Number of photos")
plt.title("Distribution of images among the labels")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', colors=['blue', 'red', 'green', 'purple'])
plt.title("Image ratio for each disease label")
plt.show()

# %%
def visualize_images(path, target_size=(250, 250), num_images=5):
    image_filenames = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
    selected_images = image_filenames[:num_images]
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3), facecolor='white')
    for i, image_filename in enumerate(selected_images):
        image_path = os.path.join(path, image_filename)
        image = Image.open(image_path)
        image = image.resize(target_size)
        axes[i].imshow(image)
        axes[i].axis('off')
        axes[i].set_title(image_filename)
    plt.tight_layout()
    plt.show()

# %%
cataract = "/content/dataset/cataract"
visualize_images(cataract, num_images=5)

# %%
glaucoma = "/content/dataset/glaucoma"
visualize_images(glaucoma, num_images=5)

# %%
diabetic_retinopathy= "/content/dataset/diabetic_retinopathy"
visualize_images(diabetic_retinopathy, num_images=5)

# %%
normal= "/content/dataset/normal"
visualize_images(normal, num_images=5)

# %%
data = "/content/dataset"
rescale = tf.keras.layers.Rescaling(1./255)
# Function to load dataset
def load_dataset(directory, subset=None, validation_split=0.3, batch_size=32, shuffle=True):
    return tf.keras.utils.image_dataset_from_directory(
        directory=directory,
        batch_size=batch_size,
        image_size=(256, 256),
        validation_split=validation_split if subset else None,
        subset=subset,
        seed=123,
        label_mode='categorical',
        shuffle=shuffle
    ).map(lambda x, y: (rescale(x), y))
train_ds = load_dataset(data, subset="training")
validation_ds = load_dataset(data, subset="validation")
# Out:
# Found 4217 files belonging to 4 classes.
# Using 2952 files for training.
# Found 4217 files belonging to 4 classes.
# Using 1265 files for validation.

# %%
model = tf.keras.Sequential([
     tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
     tf.keras.layers.MaxPooling2D((2, 2)),
     tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
     tf.keras.layers.MaxPooling2D((2, 2)),
     tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
     tf.keras.layers.MaxPooling2D((2, 2)),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(64, activation='relu'),
     tf.keras.layers.Reshape((64, 1)),  # Reshape for RNN input
     tf.keras.layers.SimpleRNN(32),  # Simple RNN layer
     tf.keras.layers.Dense(4, activation='softmax')  # Output layer
 ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 57600)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       3,686,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 64, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn (SimpleRNN)               │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             132 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,744,004 (14.28 MB)
#  Trainable params: 3,744,004 (14.28 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
history = model.fit(train_ds,
                    validation_data=validation_ds,
                    callbacks=[
                        tf.keras.callbacks.EarlyStopping("val_accuracy", patience=3, verbose=1),
                        tf.keras.callbacks.ModelCheckpoint("Best model.keras", monitor="val_accuracy", save_best_only=True)
                    ],
                    epochs=50)
# Out:
# Epoch 1/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 230ms/step - accuracy: 0.3526 - loss: 1.3291 - val_accuracy: 0.5913 - val_loss: 0.9004
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 23s 246ms/step - accuracy: 0.5971 - loss: 0.8431 - val_accuracy: 0.6356 - val_loss: 0.8696
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - accuracy: 0.6201 - loss: 0.7981 - val_accuracy: 0.6356 - val_loss: 0.7689
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.6568 - loss: 0.7525 - val_accuracy: 0.6909 - val_loss: 0.6886
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.7061 - loss: 0.6797 - val_accuracy: 0.7012 - val_loss: 0.6666
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - accuracy: 0.7306 - loss: 0.6358 - val_accuracy: 0.6783 - val_loss: 0.7054
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.7311 - loss: 0.6226 - val_accuracy: 0.7407 - val_loss: 0.6162
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.7462 - loss: 0.5912 - val_accuracy: 0.7202 - val_loss: 0.6327
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.7345 - loss: 0.6126 - val_accuracy: 0.7249 - val_loss: 0.6289
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 22s 191ms/step - accuracy: 0.7487 - loss: 0.5906 - val_accuracy: 0.7486 - val_loss: 0.5721
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 19s 178ms/step - accuracy: 0.7658 - loss: 0.5566 - val_accuracy: 0.7186 - val_loss: 0.6526
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 23s 244ms/step - accuracy: 0.7855 - loss: 0.5401 - val_accuracy: 0.7652 - val_loss: 0.5661
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.7940 - loss: 0.5214 - val_accuracy: 0.7194 - val_loss: 0.6471
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.7835 - loss: 0.5396 - val_accuracy: 0.7874 - val_loss: 0.5340
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - accuracy: 0.8248 - loss: 0.4626 - val_accuracy: 0.7802 - val_loss: 0.5406
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.8034 - loss: 0.4894 - val_accuracy: 0.7826 - val_loss: 0.5292
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.8243 - loss: 0.4498 - val_accuracy: 0.7960 - val_loss: 0.5018
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.8489 - loss: 0.4112 - val_accuracy: 0.8000 - val_loss: 0.5096
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.8511 - loss: 0.3967 - val_accuracy: 0.8063 - val_loss: 0.5011
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - accuracy: 0.8475 - loss: 0.3949 - val_accuracy: 0.8142 - val_loss: 0.4962
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 187ms/step - accuracy: 0.8817 - loss: 0.3407 - val_accuracy: 0.8206 - val_loss: 0.4790
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 23s 244ms/step - accuracy: 0.8764 - loss: 0.3299 - val_accuracy: 0.8213 - val_loss: 0.4967
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 185ms/step - accuracy: 0.8899 - loss: 0.3100 - val_accuracy: 0.7937 - val_loss: 0.5714
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.8875 - loss: 0.3093 - val_accuracy: 0.8308 - val_loss: 0.4813
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 17s 186ms/step - accuracy: 0.9087 - loss: 0.2624 - val_accuracy: 0.7968 - val_loss: 0.5548
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.9095 - loss: 0.2567 - val_accuracy: 0.8071 - val_loss: 0.5477
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.8832 - loss: 0.3090 - val_accuracy: 0.8190 - val_loss: 0.5190
# Epoch 27: early stopping

# %%
model.save('Final eye_disease_model.keras')

# %%
# !sha256sum "Best model.keras"
# Out:
# 65c3e51400df738672a320901fc072f8e9e844b68088473af33ccd801fcb665e  Best model.keras

# %%
best_model = tf.keras.models.load_model("Best model.keras")

# %%
best_model.evaluate(validation_ds, return_dict=True)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.8305 - loss: 0.4716
# {'accuracy': 0.8308300375938416, 'loss': 0.48133260011672974}

# %%
train_ds.cardinality()
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=93>

# %%
import tensorflow as tf
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model("/content/Best model.keras")  # Ensure correct model path

# Class labels
class_labels = ["Cataract", "Diabetic Retinopathy", "Glaucoma", "Normal Image"]

def predict_image(image_path):
    """Predicts the class of an input image."""
    img = tf.keras.utils.load_img(image_path, target_size=(256, 256))
    img = tf.keras.utils.img_to_array(img, dtype=np.float64) / 255.0
    predictions = model.predict(np.array([img]))

    # Print raw predictions for debugging
    print(f"Raw Predictions: {predictions}")

    class_index = np.argmax(predictions)  # Get the highest probability index
    return class_labels[class_index], np.max(predictions)

# Example usage
image_path = "/content/dataset/diabetic_retinopathy/1012_left.jpeg"  # Replace with actual image path
result, confidence = predict_image(image_path)
print(f"Predicted Class: {result}\nConfidence: {confidence * 100:.2f}")

tf.keras.utils.load_img(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Raw Predictions: [[4.7695867e-04 9.9728346e-01 5.5448822e-05 2.1842227e-03]]
# Predicted Class: Diabetic Retinopathy
# Confidence: 99.73
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
